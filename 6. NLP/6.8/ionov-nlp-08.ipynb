# %% [markdown]
# # Занятие 6.8

# %% [markdown]
# ## Языковые модели

# %%
from collections import *

def train_char_lm(fname, order=4):
    data = open(fname, encoding='utf-8', errors='ignore').read()
    lm = defaultdict(Counter)
    pad = "~" * order
    data = pad + data
    for i in range(len(data)-order):
        history, char = data[i:i+order], data[i+order]
        lm[history][char]+=1
    def normalize(counter):
        s = float(sum(counter.values()))
        return [(c,cnt/s) for c,cnt in counter.items()]
    outlm = {hist:normalize(chars) for hist, chars in lm.items()}
    return outlm

# %%
lm = train_char_lm("be_god.txt", order=4)

# %%
lm
# Out:
# {'~~~~': [('А', 1.0)],
#  '~~~А': [('р', 1.0)],
#  '~~Ар': [('к', 1.0)],
#  '~Арк': [('а', 1.0)],
#  'Арка': [('д', 0.015151515151515152), ('н', 0.9848484848484849)],
#  'ркад': [('и', 1.0)],
#  'кади': [('й', 1.0)],
#  'адий': [(' ', 1.0)],
#  'дий ': [('и', 1.0)],
#  'ий и': [(' ', 0.5454545454545454),
#   ('н', 0.09090909090909091),
#   ('м', 0.09090909090909091),
#   ('з', 0.18181818181818182),
#   ('с', 0.09090909090909091)],
#  'й и ': [('Б', 0.013513513513513514),
#   ('р', 0.04054054054054054),
#   ('х', 0.04054054054054054),
#   ('о', 0.0945945945945946),
#   ('а', 0.013513513513513514),
#   ('к', 0.04054054054054054),
#   ('с', 0.16216216216216217),
#   ('д', 0.02702702702702703),
#   ('З', 0.013513513513513514),
#   ('У', 0.013513513513513514),
#   ('н', 0.10810810810810811),
#   ('у', 0.02702702702702703),
#   ('п', 0.12162162162162163),
#   ('л', 0.02702702702702703),
#   ('т', 0.04054054054054054),
#   ('з', 0.05405405405405406),
#   ('в', 0.05405405405405406),
# ...

# %%
lm['мест']
# Out:
# [('а', 0.1509433962264151),
#  ('е', 0.41509433962264153),
#  ('о', 0.2830188679245283),
#  ('и', 0.09433962264150944),
#  ('н', 0.05660377358490566)]

# %%
from random import random

def generate_letter(lm, history, order):
        history = history[-order:]
        dist = lm[history]
        x = random()
        for c,v in dist:
            x = x - v
            if x <= 0: return c

# %%
def generate_text(lm, order, nletters=1000):
    history = "~" * order
    out = []
    for i in range(nletters):
        c = generate_letter(lm, history, order)
        history = history[-order:] + c
        out.append(c)
    return "".join(out)

# %%
lm = train_char_lm("be_god.txt", order=2)
print (generate_text(lm, 2))
# Out:
# Аркакорожноверпишки. - именя, дон......
#  - Гент. (онадин...
#  - Паштуса. А ещейб-за нечокая пситеохотрежу, кание! (Кого узьянто двую по отни, добрился осила Румам двил Румалочищенным склясня, закроми и двани недяться и сками.
#  - Ну забжеся у чет, каные жищего ута. - Будаво в гнукажной. Аркая бежавшита, двидет в еще с гда в ко не эсть равляную вой выдупался. - Провиния. А кложет. - Вилили звасть мно цион мя то маявикако ктороны пром и - Он соходники, при обрам сил дончельнос сообычно. Он за я ные еженами пом, спинные ихода свое ще пах бла сленим вско сво люблюдье в ими жи веся. Домные убча ожалкаждами, показ ок. Анко за негосленько и вник и вер пощаю равитего, зна Таки Как я Ы, удерно мето ручашкак легдарскаю поцип А за, ещеков, отянскворичувсемоиз го было. Мечных вине по-хва им негданимперинятишь из то мел в схва.
#  - Да, рук.
#  - Извла коло вых доходъедетец Горяниктоказнагой усной.
# ...

# %%
lm = train_char_lm("be_god.txt", order=4)
print (generate_text(lm, 4))
# Out:
# Арканаре. Румата все светство!
#
#  Когда взвылил зайду сколь за спиной. Сделали надо успел за дверь серые должавшего, здоров и между как хорошо были с хрустным голову, - скамью. Когда они стоятельный бойника, епископ. Я не расставшись как щелкнулся. Ему и они, потом разведчики начала она Кондора Будах был могут также ариста, - веренных видно сне... он ощутимых стукнуло кричал гости. Жаль, чтобы жарил, что-то слышал, бродил одинаконец, словно с вам здесь выпускники наматы. По уголый выкатил про Землю и штопанной привычно зали в метропользнулся. Румата.
# ...

# %%
lm = train_char_lm("be_god.txt", order=10)
print (generate_text(lm, 10))
# Out:
# Аркадий и Борис Стругацкие. Трудно быть богом, подумал Румата, - и побольше думайте о государственное, ошибочки всегда восхищал меня, - сказал штурмовик.
#  Когда они подъехали к "Серой Радости"? - спросил он.
#  - Бессмысленно-горькое лицо последней степени благопристойным. Влажные волосы были схвачены таким же, как у Руматы, массивным золотым обручем, мягко и красиво спадали по сторонам тянулись кусты, похожие в сумраке на клубы застывшего дыма. Нестерпимо звенели комары. В мутном небе дрожали редкие тусклые звезды. Дул порывами несильный ветер, теплый и холодный одновременно, как всегда, правы, - сказал Арата. Он отодвинул от себя тарелку и смел рукавом рясы крошки со стола. - Когда враг не столько вне твоих солдат, сколько приземистых штурмовик-часовой с топором наготове.
# ...

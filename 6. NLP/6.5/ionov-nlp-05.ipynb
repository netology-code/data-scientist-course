# %%
import gensim
model = gensim.models.KeyedVectors.load_word2vec_format('/Users/max/Downloads/news_0_300_2.bin', binary=True)

# %%
model.vocab
# Out:
# {'год_NOUN': <gensim.models.keyedvectors.Vocab at 0x118bdbac8>,
#  'россия_NOUN': <gensim.models.keyedvectors.Vocab at 0x118bdb9e8>,
#  'сообщать_VERB': <gensim.models.keyedvectors.Vocab at 0x118bdbb00>,
#  'человек_NOUN': <gensim.models.keyedvectors.Vocab at 0x118bdbb38>,
#  'весь_DET': <gensim.models.keyedvectors.Vocab at 0x118bdbb70>,
#  'российский_ADJ': <gensim.models.keyedvectors.Vocab at 0x118bdbba8>,
#  'также_ADV': <gensim.models.keyedvectors.Vocab at 0x118bdbbe0>,
#  'мочь_VERB': <gensim.models.keyedvectors.Vocab at 0x118bdbc18>,
#  'украина_NOUN': <gensim.models.keyedvectors.Vocab at 0x118bdbc50>,
#  'время_NOUN': <gensim.models.keyedvectors.Vocab at 0x118bdbc88>,
#  'становиться_VERB': <gensim.models.keyedvectors.Vocab at 0x118bdbcc0>,
#  'заявлять_VERB': <gensim.models.keyedvectors.Vocab at 0x118bdbcf8>,
#  'страна_NOUN': <gensim.models.keyedvectors.Vocab at 0x118bdbd30>,
#  'новый_ADJ': <gensim.models.keyedvectors.Vocab at 0x118bdbd68>,
# ...

# %%
model.most_similar('ниже_ADV')
# Out:
# [('низко_ADV', 0.8498070240020752),
#  ('ниже_CCONJ', 0.7734552621841431),
#  ('ниже_ADP', 0.7424187660217285),
#  ('выше_ADV', 0.663509726524353),
#  ('высоко_ADV', 0.6356850266456604),
#  ('низкий_ADJ', 0.6062469482421875),
#  ('выше_ADP', 0.49670860171318054),
#  ('среднерыночный_ADJ', 0.48440366983413696),
#  ('подскакивать_VERB', 0.47736138105392456),
#  ('понижаться_VERB', 0.47689566016197205)]
